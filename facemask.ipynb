# %% [markdown]
# <a href="https://colab.research.google.com/github/jishnuks17/Machine-Learning-Algorithms/blob/main/facemask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Karan-Malik/FaceMaskDetector
# Out:
# Cloning into 'FaceMaskDetector'...
# remote: Enumerating objects: 1543, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 1543 (delta 44), reused 72 (delta 31), pack-reused 1454
# Receiving objects: 100% (1543/1543), 84.40 MiB | 38.07 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
import numpy as np
import keras
import keras.backend as k
from keras.layers import Conv2D,MaxPooling2D,SpatialDropout2D,Flatten,Dropout,Dense
from keras.models import Sequential,load_model
from keras.preprocessing import image
import cv2
import datetime

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Flatten())
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
training_set = train_datagen.flow_from_directory(
        '/content/FaceMaskDetector/train',
        target_size=(150,150),
        batch_size=16 ,
        class_mode='binary')
# Out:
# Found 1314 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
        '/content/FaceMaskDetector/test',
        target_size=(150,150),
        batch_size=16,
        class_mode='binary')
# Out:
# Found 194 images belonging to 2 classes.

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_saved=model.fit_generator(
        training_set,
        epochs=25,
        validation_data=test_set,
        )
# Out:
# Epoch 1/25
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# 83/83 [==============================] - 45s 539ms/step - loss: 0.0369 - accuracy: 0.9901 - val_loss: 0.2139 - val_accuracy: 0.9536
# Epoch 2/25
# 83/83 [==============================] - 47s 562ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.1701 - val_accuracy: 0.9691
# Epoch 3/25
# 83/83 [==============================] - 46s 552ms/step - loss: 0.0148 - accuracy: 0.9939 - val_loss: 0.1661 - val_accuracy: 0.9588
# Epoch 4/25
# 83/83 [==============================] - 46s 553ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.1117 - val_accuracy: 0.9639
# Epoch 5/25
# 83/83 [==============================] - 46s 552ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9536
# Epoch 6/25
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 9248)              0
#
#  dense (Dense)               (None, 100)               924900
#
#  dense_1 (Dense)             (None, 1)                 101
#
# ...
# Total params: 944,393
# Trainable params: 944,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('mymodel.h5',model_saved)

# %%
mymodel=load_model('mymodel.h5')

# %%
import cv2
import matplotlib.pyplot as plt

# %%
test_image=image.load_img('/content/FaceMaskDetector/test/with_mask/111-with-mask.jpg',
                          target_size=(150,150,3))
test_image
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
if(mymodel.predict(test_image)[0][0] == 0):
  print("With Mask")
else:
  print("Without Mask")
# Out:
# With Mask

# %%
im = cv2.imread('/content/FaceMaskDetector/test/with_mask/111-with-mask.jpg')
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
test_image=image.load_img('/content/FaceMaskDetector/test/without_mask/122.jpg',
                          target_size=(150,150,3))
test_image
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
if(mymodel.predict(test_image)[0][0] == 0):
  print("With Mask")
else:
  print("Without Mask")
# Out:
# Without Mask

# %%
im = cv2.imread('/content/FaceMaskDetector/test/without_mask/122.jpg')
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
test_image=image.load_img(filename,
                          target_size=(150,150,3))
test_image
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
if(mymodel.predict(test_image)[0][0] == 0):
  print("With Mask")
else:
  print("Without Mask")
# Out:
# With Mask
